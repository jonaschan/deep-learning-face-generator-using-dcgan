# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
use_temp_storage = True

if use_temp_storage:
    print("Accessing temporary storage for Face Detection data...")
    data_dir = '../face-detection-data'
else:
    data_dir = './data'
        
        

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Accessing temporary storage for Face Detection data...
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# /anaconda3/envs/dlnd_tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    
    real_input = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name = "real_input")
    z_input = tf.placeholder(tf.float32, (None, z_dim), name = "z_input")
    learning_rate = tf.placeholder(tf.float32, name = "learning_rate")
    
    # TODO: Implement Function

    return real_input, z_input, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        
        alpha = 0.2
        keep_prob = 0.9
        # Input layer is 32x32x3
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        relu1 = tf.maximum(alpha * x1, x1)
        # 16x16x64
        
        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same')
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(alpha * bn2, bn2)
        relu2 = tf.nn.dropout(relu2, keep_prob=keep_prob)

        # 8x8x128
        
        x3 = tf.layers.conv2d(relu2, 256, 5, strides=2, padding='same')
        bn3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(alpha * bn3, bn3)
        relu3 = tf.nn.dropout(relu3, keep_prob=keep_prob)
        # 4x4x256

        # Flatten it
        flat = tf.reshape(relu3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse=not is_train):

        alpha = 0.2
        keep_prob = 0.9
        # First fully connected layer
        x1 = tf.layers.dense(z, 7*7*512)
        # Reshape it to start the convolutional stack
        x1 = tf.reshape(x1, (-1, 7, 7, 512))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(alpha * x1, x1)
        # 2x2x512 now
        
        x2 = tf.layers.conv2d_transpose(x1, 256, 5, strides=2, padding='same')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(alpha * x2, x2)
        x2 = tf.nn.dropout(x2, keep_prob=keep_prob)

        # 7x7x256 now
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides=2, padding='same')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(alpha * x3, x3)
        x3 = tf.nn.dropout(x3, keep_prob=keep_prob)

        # 14x14x128 now

        # Output layer
        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides=1, padding='same')
        # 28x28x3 now
        
        out = tf.tanh(logits)
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss_total = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss_total = d_loss_real + d_loss_fake
    return d_loss_total, g_loss_total


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.
#
# show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode)

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    # 1. Get the data information
    _, image_width, image_height, image_channels = data_shape
    
    # 2. Get input data
    real_input, z_input, lr = model_inputs(image_width, image_height, image_channels, z_dim)
    
    # 3. Get generator and discriminator losses
    d_loss, g_loss = model_loss(real_input, z_input, image_channels)
    
    # 4. Get optimiser
    d_opt, g_opt = model_opt(d_loss, g_loss, lr, beta1)
    
    step = 0
    losses = []
    n_images = 20
    show_every = 100
    print_every = 10
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                step += 1
                batch_images *= 2.0
                
                # Sample random noise for the Generator to be fed into the generator
                batch_z = np.random.uniform(-1, 1, size = (batch_size, z_dim))
                
                # Running optimisers
                _ = sess.run(d_opt, feed_dict = {real_input: batch_images, 
                                                 z_input: batch_z, 
                                                 lr: learning_rate})
                _ = sess.run(g_opt, feed_dict = {real_input: batch_images, 
                                                 z_input: batch_z, 
                                                 lr: learning_rate})
                
                if step % print_every == 0:
                    train_loss_d = d_loss.eval({z_input: batch_z, real_input: batch_images})
                    train_loss_g = g_loss.eval({z_input: batch_z})
                    
                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    losses.append((train_loss_d, train_loss_g))
                    
                if step % show_every == 0:
                    show_generator_output(sess, n_images, z_input, image_channels, data_image_mode)
                    
        saver.save(sess, "./checkpoints/generator.ckpt")

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.2316... Generator Loss: 2.4272
# Epoch 1/2... Discriminator Loss: 0.0530... Generator Loss: 3.9300
# Epoch 1/2... Discriminator Loss: 0.0785... Generator Loss: 3.8781
# Epoch 1/2... Discriminator Loss: 1.4575... Generator Loss: 1.7619
# Epoch 1/2... Discriminator Loss: 0.9770... Generator Loss: 2.5843
# Epoch 1/2... Discriminator Loss: 0.9758... Generator Loss: 0.7986
# Epoch 1/2... Discriminator Loss: 0.6121... Generator Loss: 2.7475
# Epoch 1/2... Discriminator Loss: 1.3386... Generator Loss: 0.7663
# Epoch 1/2... Discriminator Loss: 1.2444... Generator Loss: 1.1108
# Epoch 1/2... Discriminator Loss: 1.0305... Generator Loss: 1.1065
# Epoch 1/2... Discriminator Loss: 1.3774... Generator Loss: 1.4357
# Epoch 1/2... Discriminator Loss: 1.1287... Generator Loss: 1.7162
# Epoch 1/2... Discriminator Loss: 1.2859... Generator Loss: 0.9139
# Epoch 1/2... Discriminator Loss: 1.1967... Generator Loss: 0.6791
# Epoch 1/2... Discriminator Loss: 1.0289... Generator Loss: 1.0536
# Epoch 1/2... Discriminator Loss: 1.3403... Generator Loss: 0.7565
# Epoch 1/2... Discriminator Loss: 1.2360... Generator Loss: 0.6705
# Epoch 1/2... Discriminator Loss: 1.0760... Generator Loss: 0.8863
# Epoch 1/2... Discriminator Loss: 0.9205... Generator Loss: 1.1567
# Epoch 1/2... Discriminator Loss: 1.0022... Generator Loss: 1.0354
# Epoch 1/2... Discriminator Loss: 1.0417... Generator Loss: 0.8535
# Epoch 1/2... Discriminator Loss: 0.8953... Generator Loss: 1.2179
# Epoch 1/2... Discriminator Loss: 1.1304... Generator Loss: 0.6912
# Epoch 1/2... Discriminator Loss: 0.8181... Generator Loss: 1.1259
# Epoch 1/2... Discriminator Loss: 0.8817... Generator Loss: 1.6028
# Epoch 1/2... Discriminator Loss: 0.9179... Generator Loss: 0.8470
# Epoch 1/2... Discriminator Loss: 1.0753... Generator Loss: 2.0604
# Epoch 1/2... Discriminator Loss: 0.9929... Generator Loss: 0.8307
# Epoch 1/2... Discriminator Loss: 0.7651... Generator Loss: 1.6494
# Epoch 1/2... Discriminator Loss: 0.8127... Generator Loss: 1.2298
# Epoch 1/2... Discriminator Loss: 1.2405... Generator Loss: 0.4749
# Epoch 1/2... Discriminator Loss: 0.8439... Generator Loss: 1.2085
# Epoch 1/2... Discriminator Loss: 1.0670... Generator Loss: 0.9033
# Epoch 1/2... Discriminator Loss: 1.0583... Generator Loss: 1.3385
# Epoch 1/2... Discriminator Loss: 1.0015... Generator Loss: 1.9323
# Epoch 1/2... Discriminator Loss: 1.0396... Generator Loss: 0.7830
# Epoch 1/2... Discriminator Loss: 1.1075... Generator Loss: 2.0455
# Epoch 1/2... Discriminator Loss: 1.0691... Generator Loss: 0.7850
# Epoch 1/2... Discriminator Loss: 1.1587... Generator Loss: 0.8984
# Epoch 1/2... Discriminator Loss: 1.0517... Generator Loss: 1.4562
# Epoch 1/2... Discriminator Loss: 1.0200... Generator Loss: 1.4292
# Epoch 1/2... Discriminator Loss: 1.1433... Generator Loss: 0.6433
# Epoch 1/2... Discriminator Loss: 1.1719... Generator Loss: 1.6419
# Epoch 1/2... Discriminator Loss: 1.0488... Generator Loss: 0.7264
# Epoch 1/2... Discriminator Loss: 1.0434... Generator Loss: 1.3357
# Epoch 1/2... Discriminator Loss: 0.9427... Generator Loss: 1.0517
# Epoch 2/2... Discriminator Loss: 1.0379... Generator Loss: 0.8664
# Epoch 2/2... Discriminator Loss: 1.0160... Generator Loss: 0.9331
# Epoch 2/2... Discriminator Loss: 1.1589... Generator Loss: 0.7027
# Epoch 2/2... Discriminator Loss: 1.1414... Generator Loss: 0.8370
# Epoch 2/2... Discriminator Loss: 0.8842... Generator Loss: 1.0820
# Epoch 2/2... Discriminator Loss: 1.1305... Generator Loss: 0.7140
# Epoch 2/2... Discriminator Loss: 0.9871... Generator Loss: 0.9855
# Epoch 2/2... Discriminator Loss: 1.2857... Generator Loss: 0.4934
# Epoch 2/2... Discriminator Loss: 1.0354... Generator Loss: 1.4605
# Epoch 2/2... Discriminator Loss: 1.0626... Generator Loss: 1.1003
# Epoch 2/2... Discriminator Loss: 1.0763... Generator Loss: 0.7004
# Epoch 2/2... Discriminator Loss: 1.0279... Generator Loss: 0.9629
# Epoch 2/2... Discriminator Loss: 1.2125... Generator Loss: 0.6929
# Epoch 2/2... Discriminator Loss: 0.9996... Generator Loss: 0.9607
# Epoch 2/2... Discriminator Loss: 1.1281... Generator Loss: 0.5338
# Epoch 2/2... Discriminator Loss: 0.9657... Generator Loss: 1.3304
# Epoch 2/2... Discriminator Loss: 1.0734... Generator Loss: 1.1589
# Epoch 2/2... Discriminator Loss: 1.0680... Generator Loss: 0.9898
# Epoch 2/2... Discriminator Loss: 1.2282... Generator Loss: 0.5304
# Epoch 2/2... Discriminator Loss: 1.0995... Generator Loss: 0.9069
# Epoch 2/2... Discriminator Loss: 1.1059... Generator Loss: 1.3728
# Epoch 2/2... Discriminator Loss: 1.0496... Generator Loss: 1.3860
# Epoch 2/2... Discriminator Loss: 0.8376... Generator Loss: 1.2662
# Epoch 2/2... Discriminator Loss: 1.0740... Generator Loss: 0.8812
# Epoch 2/2... Discriminator Loss: 1.0544... Generator Loss: 0.8976
# Epoch 2/2... Discriminator Loss: 0.9618... Generator Loss: 1.4353
# Epoch 2/2... Discriminator Loss: 1.1571... Generator Loss: 1.0324
# Epoch 2/2... Discriminator Loss: 0.9705... Generator Loss: 0.9438
# Epoch 2/2... Discriminator Loss: 1.0629... Generator Loss: 0.7590
# Epoch 2/2... Discriminator Loss: 0.9581... Generator Loss: 1.3247
# Epoch 2/2... Discriminator Loss: 1.0066... Generator Loss: 0.7923
# Epoch 2/2... Discriminator Loss: 1.2102... Generator Loss: 0.6426
# Epoch 2/2... Discriminator Loss: 1.1658... Generator Loss: 1.5557
# Epoch 2/2... Discriminator Loss: 0.9288... Generator Loss: 1.3598
# Epoch 2/2... Discriminator Loss: 1.0821... Generator Loss: 0.6886
# Epoch 2/2... Discriminator Loss: 0.9665... Generator Loss: 1.0500
# Epoch 2/2... Discriminator Loss: 0.9666... Generator Loss: 0.8178
# Epoch 2/2... Discriminator Loss: 1.0482... Generator Loss: 1.7675
# Epoch 2/2... Discriminator Loss: 0.9861... Generator Loss: 0.7551
# Epoch 2/2... Discriminator Loss: 1.0330... Generator Loss: 1.3549
# Epoch 2/2... Discriminator Loss: 1.0041... Generator Loss: 1.3451
# Epoch 2/2... Discriminator Loss: 0.8359... Generator Loss: 1.2194
# Epoch 2/2... Discriminator Loss: 0.9912... Generator Loss: 0.9673
# Epoch 2/2... Discriminator Loss: 1.1432... Generator Loss: 1.6276
# Epoch 2/2... Discriminator Loss: 1.0035... Generator Loss: 0.8010
# Epoch 2/2... Discriminator Loss: 0.9705... Generator Loss: 1.2633
# Epoch 2/2... Discriminator Loss: 0.9088... Generator Loss: 1.1561

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.4029... Generator Loss: 1.6972
# Epoch 1/1... Discriminator Loss: 0.3665... Generator Loss: 2.0942
# Epoch 1/1... Discriminator Loss: 0.1992... Generator Loss: 2.7270
# Epoch 1/1... Discriminator Loss: 1.3479... Generator Loss: 9.5204
# Epoch 1/1... Discriminator Loss: 0.7990... Generator Loss: 1.4975
# Epoch 1/1... Discriminator Loss: 0.6409... Generator Loss: 1.5516
# Epoch 1/1... Discriminator Loss: 0.5908... Generator Loss: 2.2416
# Epoch 1/1... Discriminator Loss: 0.3349... Generator Loss: 2.1532
# Epoch 1/1... Discriminator Loss: 0.3957... Generator Loss: 3.4905
# Epoch 1/1... Discriminator Loss: 0.1923... Generator Loss: 2.9226
# Epoch 1/1... Discriminator Loss: 0.2497... Generator Loss: 2.9650
# Epoch 1/1... Discriminator Loss: 0.1641... Generator Loss: 2.5513
# Epoch 1/1... Discriminator Loss: 0.2582... Generator Loss: 1.9434
# Epoch 1/1... Discriminator Loss: 0.3565... Generator Loss: 1.8861
# Epoch 1/1... Discriminator Loss: 0.0912... Generator Loss: 3.8378
# Epoch 1/1... Discriminator Loss: 0.1980... Generator Loss: 2.2967
# Epoch 1/1... Discriminator Loss: 0.3897... Generator Loss: 2.8205
# Epoch 1/1... Discriminator Loss: 0.1565... Generator Loss: 2.8911
# Epoch 1/1... Discriminator Loss: 0.4437... Generator Loss: 3.7994
# Epoch 1/1... Discriminator Loss: 0.4457... Generator Loss: 1.8317
# Epoch 1/1... Discriminator Loss: 0.3678... Generator Loss: 2.0761
# Epoch 1/1... Discriminator Loss: 0.6389... Generator Loss: 3.3788
# Epoch 1/1... Discriminator Loss: 0.6341... Generator Loss: 3.2284
# Epoch 1/1... Discriminator Loss: 0.8478... Generator Loss: 0.7542
# Epoch 1/1... Discriminator Loss: 0.7333... Generator Loss: 1.3315
# Epoch 1/1... Discriminator Loss: 0.6205... Generator Loss: 1.6820
# Epoch 1/1... Discriminator Loss: 0.2621... Generator Loss: 2.7993
# Epoch 1/1... Discriminator Loss: 0.8052... Generator Loss: 2.6207
# Epoch 1/1... Discriminator Loss: 1.1343... Generator Loss: 0.5868
# Epoch 1/1... Discriminator Loss: 1.5058... Generator Loss: 4.6113
# Epoch 1/1... Discriminator Loss: 0.6787... Generator Loss: 1.1224
# Epoch 1/1... Discriminator Loss: 0.7679... Generator Loss: 1.2457
# Epoch 1/1... Discriminator Loss: 1.0892... Generator Loss: 2.8252
# Epoch 1/1... Discriminator Loss: 0.7007... Generator Loss: 1.5030
# Epoch 1/1... Discriminator Loss: 0.7370... Generator Loss: 1.5098
# Epoch 1/1... Discriminator Loss: 0.7705... Generator Loss: 2.0835
# Epoch 1/1... Discriminator Loss: 1.1855... Generator Loss: 0.5609
# Epoch 1/1... Discriminator Loss: 0.6847... Generator Loss: 1.2094
# Epoch 1/1... Discriminator Loss: 0.8271... Generator Loss: 2.4059
# Epoch 1/1... Discriminator Loss: 1.7266... Generator Loss: 0.3084
# Epoch 1/1... Discriminator Loss: 0.9096... Generator Loss: 0.9907
# Epoch 1/1... Discriminator Loss: 1.1891... Generator Loss: 2.8243
# Epoch 1/1... Discriminator Loss: 0.9038... Generator Loss: 0.9494
# Epoch 1/1... Discriminator Loss: 0.9392... Generator Loss: 0.7804
# Epoch 1/1... Discriminator Loss: 1.0734... Generator Loss: 0.8553
# Epoch 1/1... Discriminator Loss: 1.0370... Generator Loss: 1.2516
# Epoch 1/1... Discriminator Loss: 0.9761... Generator Loss: 1.3627
# Epoch 1/1... Discriminator Loss: 0.9563... Generator Loss: 1.5685
# Epoch 1/1... Discriminator Loss: 0.8369... Generator Loss: 1.0350
# Epoch 1/1... Discriminator Loss: 1.4511... Generator Loss: 0.3472
# Epoch 1/1... Discriminator Loss: 0.7943... Generator Loss: 1.0913
# Epoch 1/1... Discriminator Loss: 1.0991... Generator Loss: 2.8897
# Epoch 1/1... Discriminator Loss: 0.7893... Generator Loss: 1.0734
# Epoch 1/1... Discriminator Loss: 1.3170... Generator Loss: 3.5035
# Epoch 1/1... Discriminator Loss: 0.9328... Generator Loss: 2.4635
# Epoch 1/1... Discriminator Loss: 1.0138... Generator Loss: 0.7073
# Epoch 1/1... Discriminator Loss: 0.8252... Generator Loss: 1.5224
# Epoch 1/1... Discriminator Loss: 0.8587... Generator Loss: 1.0357
# Epoch 1/1... Discriminator Loss: 1.0015... Generator Loss: 0.8231
# Epoch 1/1... Discriminator Loss: 0.9678... Generator Loss: 1.1425
# Epoch 1/1... Discriminator Loss: 0.7718... Generator Loss: 1.1157
# Epoch 1/1... Discriminator Loss: 0.8706... Generator Loss: 1.0202
# Epoch 1/1... Discriminator Loss: 1.1517... Generator Loss: 0.5358
# Epoch 1/1... Discriminator Loss: 0.8105... Generator Loss: 1.5291
# Epoch 1/1... Discriminator Loss: 1.3817... Generator Loss: 2.5434
# Epoch 1/1... Discriminator Loss: 1.0258... Generator Loss: 1.7467
# Epoch 1/1... Discriminator Loss: 0.9004... Generator Loss: 1.9962
# Epoch 1/1... Discriminator Loss: 0.8898... Generator Loss: 1.3486
# Epoch 1/1... Discriminator Loss: 1.0188... Generator Loss: 0.7762
# Epoch 1/1... Discriminator Loss: 1.1438... Generator Loss: 0.6945
# Epoch 1/1... Discriminator Loss: 1.1866... Generator Loss: 0.5800
# Epoch 1/1... Discriminator Loss: 1.2695... Generator Loss: 0.5023
# Epoch 1/1... Discriminator Loss: 1.1118... Generator Loss: 1.5523
# Epoch 1/1... Discriminator Loss: 0.5446... Generator Loss: 2.3815
# Epoch 1/1... Discriminator Loss: 0.8247... Generator Loss: 1.0248
# Epoch 1/1... Discriminator Loss: 1.1392... Generator Loss: 1.1198
# Epoch 1/1... Discriminator Loss: 0.9471... Generator Loss: 1.0898
# Epoch 1/1... Discriminator Loss: 1.4996... Generator Loss: 3.0285
# Epoch 1/1... Discriminator Loss: 0.8506... Generator Loss: 1.1507
# Epoch 1/1... Discriminator Loss: 1.1029... Generator Loss: 0.9814
# Epoch 1/1... Discriminator Loss: 1.2558... Generator Loss: 1.9933
# Epoch 1/1... Discriminator Loss: 1.1502... Generator Loss: 1.2498
# Epoch 1/1... Discriminator Loss: 1.7316... Generator Loss: 0.3082
# Epoch 1/1... Discriminator Loss: 1.0485... Generator Loss: 0.8101
# Epoch 1/1... Discriminator Loss: 0.9552... Generator Loss: 1.3699
# Epoch 1/1... Discriminator Loss: 1.1193... Generator Loss: 0.9311
# Epoch 1/1... Discriminator Loss: 0.8447... Generator Loss: 1.2275
# Epoch 1/1... Discriminator Loss: 1.5612... Generator Loss: 2.0168
# Epoch 1/1... Discriminator Loss: 1.1212... Generator Loss: 1.0843
# Epoch 1/1... Discriminator Loss: 1.2851... Generator Loss: 0.5688
# Epoch 1/1... Discriminator Loss: 1.2120... Generator Loss: 1.2478
# Epoch 1/1... Discriminator Loss: 1.1511... Generator Loss: 1.7180
# Epoch 1/1... Discriminator Loss: 1.0504... Generator Loss: 1.4085
# Epoch 1/1... Discriminator Loss: 1.3408... Generator Loss: 0.4565
# Epoch 1/1... Discriminator Loss: 1.0907... Generator Loss: 0.7931
# Epoch 1/1... Discriminator Loss: 1.0611... Generator Loss: 0.8277
# Epoch 1/1... Discriminator Loss: 0.9437... Generator Loss: 1.2802
# Epoch 1/1... Discriminator Loss: 1.4122... Generator Loss: 0.4638
# Epoch 1/1... Discriminator Loss: 1.2154... Generator Loss: 0.5607
# Epoch 1/1... Discriminator Loss: 1.1384... Generator Loss: 0.6968
# Epoch 1/1... Discriminator Loss: 0.9512... Generator Loss: 0.9918
# Epoch 1/1... Discriminator Loss: 0.9657... Generator Loss: 1.0931
# Epoch 1/1... Discriminator Loss: 0.9916... Generator Loss: 1.3064
# Epoch 1/1... Discriminator Loss: 0.9693... Generator Loss: 0.9747
# Epoch 1/1... Discriminator Loss: 1.0456... Generator Loss: 1.0269
# Epoch 1/1... Discriminator Loss: 1.0225... Generator Loss: 0.8713
# Epoch 1/1... Discriminator Loss: 1.1089... Generator Loss: 0.8854
# Epoch 1/1... Discriminator Loss: 1.2181... Generator Loss: 0.8631
# Epoch 1/1... Discriminator Loss: 1.5729... Generator Loss: 0.4288
# Epoch 1/1... Discriminator Loss: 1.3592... Generator Loss: 0.5534
# Epoch 1/1... Discriminator Loss: 1.1664... Generator Loss: 1.6677
# Epoch 1/1... Discriminator Loss: 1.1818... Generator Loss: 0.8252
# Epoch 1/1... Discriminator Loss: 1.0957... Generator Loss: 0.8281
# Epoch 1/1... Discriminator Loss: 1.2970... Generator Loss: 0.4760
# Epoch 1/1... Discriminator Loss: 1.1416... Generator Loss: 0.6631
# Epoch 1/1... Discriminator Loss: 0.9810... Generator Loss: 1.1559
# Epoch 1/1... Discriminator Loss: 1.4374... Generator Loss: 0.4372
# Epoch 1/1... Discriminator Loss: 1.2650... Generator Loss: 0.6690
# Epoch 1/1... Discriminator Loss: 0.9083... Generator Loss: 1.1000
# Epoch 1/1... Discriminator Loss: 1.0043... Generator Loss: 1.4115
# Epoch 1/1... Discriminator Loss: 0.9763... Generator Loss: 1.2493
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-695a03cb8617> in <module>()
#      12 with tf.Graph().as_default():
#      13     train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
# ---> 14           celeba_dataset.shape, celeba_dataset.image_mode)
#
# <ipython-input-47-a53496888127> in train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode)
#      49                 _ = sess.run(g_opt, feed_dict = {real_input: batch_images,
#      50                                                  z_input: batch_z,
# ---> 51                                                  lr: learning_rate})
#      52
#      53                 if step % print_every == 0:
#
# /anaconda3/envs/dlnd_tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/envs/dlnd_tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /anaconda3/envs/dlnd_tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /anaconda3/envs/dlnd_tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /anaconda3/envs/dlnd_tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
